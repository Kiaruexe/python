# %% [markdown]
# Si en lugar de usar el servicio Detect Faces de Rekognition, quisiéramos usar el de Detect Labels, procederíamos de la misma forma, cambiando únicamente el método a llamar y el procesamiento de la respuesta.

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.40.69-py3-none-any.whl.metadata (6.8 kB)
# Collecting botocore<1.41.0,>=1.40.69 (from boto3)
#   Downloading botocore-1.40.69-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.69->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.69->boto3) (1.17.0)
# Downloading boto3-1.40.69-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 5.2 MB/s eta 0:00:00
# Downloading botocore-1.40.69-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 33.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.40.69 botocore-1.40.69 jmespath-1.0.1 s3transfer-0.14.0

# %%
import boto3

# %% [markdown]
# <h4 style="color:orange;">Paso 1. Creamos el cliente de Rekognition</h4>

# %%
REGION = 'us-east-1'  # Cambia a la región donde tienes habilitado Rekognition

# En este caso creamos el cliente haciendo uso del fichero de credenciales
rekognition_client = boto3.client(
    'rekognition',
    region_name=REGION,
    aws_access_key_id='ASIAUCOKYO6XJK44MF7U',
    aws_secret_access_key='BQ6PyL5hi6LANdKBZ+6yGUsop10lg92yKEEcqJFy',
    aws_session_token='...'
)

# %% [markdown]
# <h4 style="color:orange;">Paso 2. Leemos el fichero con el que queremos trabajar</h4>

# %%
# Leemos la imagen desde el archivo en formato binario

IMAGE_FILE_PATH = "cara1descarga.jpg"
with open(IMAGE_FILE_PATH, 'rb') as image_file:
    image_bytes = image_file.read()

# %% [markdown]
# <h4 style="color:orange;">Paso 3. Realizamos la solicitud a DETECT_LABELS</h4>

# %%
# Realizar la solicitud DetectFaces al servicio de Rekognition. En este caso, cambian ligeramente los parámetros que recibe el método
response = rekognition_client.detect_labels(
    Image={'Bytes': image_bytes},
    MaxLabels=15,            # Mostrar hasta 15 etiquetas
    MinConfidence=95.0       # Solo etiquetas con confianza >= 90%
)

# %% [markdown]
# <h4 style="color:orange;">Paso 4. Procesamos la respuesta</h4>

# %%
print(response)
# Out:
# {'Labels': [{'Name': 'Head', 'Confidence': 99.99481201171875, 'Instances': [], 'Parents': [{'Name': 'Person'}], 'Aliases': [], 'Categories': [{'Name': 'Person Description'}]}, {'Name': 'Person', 'Confidence': 99.99481201171875, 'Instances': [{'BoundingBox': {'Width': 0.815801739692688, 'Height': 0.9965455532073975, 'Left': 0.046117667108774185, 'Top': 0.0007361602620221674}, 'Confidence': 99.69603729248047}], 'Parents': [], 'Aliases': [{'Name': 'Human'}], 'Categories': [{'Name': 'Person Description'}]}, {'Name': 'Face', 'Confidence': 99.9932632446289, 'Instances': [], 'Parents': [{'Name': 'Head'}, {'Name': 'Person'}], 'Aliases': [], 'Categories': [{'Name': 'Person Description'}]}, {'Name': 'Happy', 'Confidence': 99.95347595214844, 'Instances': [], 'Parents': [{'Name': 'Face'}, {'Name': 'Head'}, {'Name': 'Person'}], 'Aliases': [], 'Categories': [{'Name': 'Expressions and Emotions'}]}, {'Name': 'Smile', 'Confidence': 99.95347595214844, 'Instances': [], 'Parents': [{'Name': 'Face'}, {'Name': 'Happy'}, {'Name': 'Head'}, {'Name': 'Person'}], 'Aliases': [], 'Categories': [{'Name': 'Expressions and Emotions'}]}, {'Name': 'Body Part', 'Confidence': 99.69783020019531, 'Instances': [], 'Parents': [], 'Aliases': [], 'Categories': [{'Name': 'Person Description'}]}, {'Name': 'Neck', 'Confidence': 99.69783020019531, 'Instances': [], 'Parents': [{'Name': 'Body Part'}, {'Name': 'Face'}, {'Name': 'Head'}, {'Name': 'Person'}], 'Aliases': [], 'Categories': [{'Name': 'Person Description'}]}, {'Name': 'Photography', 'Confidence': 99.36119842529297, 'Instances': [], 'Parents': [], 'Aliases': [{'Name': 'Photo'}], 'Categories': [{'Name': 'Hobbies and Interests'}]}, {'Name': 'Portrait', 'Confidence': 99.36119842529297, 'Instances': [], 'Parents': [{'Name': 'Face'}, {'Name': 'Head'}, {'Name': 'Person'}, {'Name': 'Photography'}], 'Aliases': [], 'Categories': [{'Name': 'Hobbies and Interests'}]}, {'Name': 'Skin', 'Confidence': 97.24162292480469, 'Instances': [], 'Parents': [{'Name': 'Person'}], 'Aliases': [], 'Categories': [{'Name': 'Person Description'}]}], 'LabelModelVersion': '3.0', 'ResponseMetadata': {'RequestId': '5e5c5603-d61c-4c6f-b752-836f7e8b4e72', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5e5c5603-d61c-4c6f-b752-836f7e8b4e72', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1918', 'date': 'Mon, 10 Nov 2025 19:05:09 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# **Estructura de la respuesta**
#
# La respuesta de detect_labels es un diccionario que contiene información sobre las etiquetas detectadas. Donde:
# * **Labels**: Contiene las etiquetas detectadas con:
#     1. **Name**: El nombre de la etiqueta (por ejemplo, "Person", "Tree").
#     2. **Confidence**: La confianza de que la etiqueta sea correcta, en porcentaje.
#     3. **Instances**: Si aplica, contiene instancias de los objetos detectados con su BoundingBox (rectángulo de localización).
#     4. **Parents**: Las categorías generales a las que pertenece la etiqueta (por ejemplo, "Person" puede tener "Human" como padre).

# %%
# Mostrar etiquetas detectadas
for label in response['Labels']:
    print(f"Etiqueta: {label['Name']}, Confianza: {label['Confidence']}, Categorías superiores:{label['Parents']}")
# Out:
# Etiqueta: Head, Confianza: 99.99481201171875, Categorías superiores:[{'Name': 'Person'}]
# Etiqueta: Person, Confianza: 99.99481201171875, Categorías superiores:[]
# Etiqueta: Face, Confianza: 99.9932632446289, Categorías superiores:[{'Name': 'Head'}, {'Name': 'Person'}]
# Etiqueta: Happy, Confianza: 99.95347595214844, Categorías superiores:[{'Name': 'Face'}, {'Name': 'Head'}, {'Name': 'Person'}]
# Etiqueta: Smile, Confianza: 99.95347595214844, Categorías superiores:[{'Name': 'Face'}, {'Name': 'Happy'}, {'Name': 'Head'}, {'Name': 'Person'}]
# Etiqueta: Body Part, Confianza: 99.69783020019531, Categorías superiores:[]
# Etiqueta: Neck, Confianza: 99.69783020019531, Categorías superiores:[{'Name': 'Body Part'}, {'Name': 'Face'}, {'Name': 'Head'}, {'Name': 'Person'}]
# Etiqueta: Photography, Confianza: 99.36119842529297, Categorías superiores:[]
# Etiqueta: Portrait, Confianza: 99.36119842529297, Categorías superiores:[{'Name': 'Face'}, {'Name': 'Head'}, {'Name': 'Person'}, {'Name': 'Photography'}]
# Etiqueta: Skin, Confianza: 97.24162292480469, Categorías superiores:[{'Name': 'Person'}]
